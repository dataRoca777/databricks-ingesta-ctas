# %%
# %sql
SHOW CATALOGS;

# %%
# %sql
SHOW SCHEMAS IN workspace;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS workspace.demo_ctas;

# %%
# %sql
SHOW SCHEMAS IN workspace;

# %%
# %sql
SHOW VOLUMES IN workspace.demo_ctas;

# %%
# %sql
CREATE VOLUME workspace.demo_ctas.DemoCuentas;

# %%
# %sql
SHOW VOLUMES IN workspace.demo_ctas;

# %%
# %sql
LIST '/Volumes/workspace/demo_ctas/democuentas';

# %%
# %sql

LIST '/Volumes/workspace/demo_ctas/files/personas';

# %%
# %sql

LIST '/Volumes/workspace/demo_ctas/files/';

# %%
# %sql
SHOW VOLUMES IN workspace.demo_ctas;

# %%
# %sql

SELECT *
FROM parquet.`/Volumes/workspace/demo_ctas/files/personas/personas1.parquet`;

# %%
# %sql

SELECT *
FROM parquet.`/Volumes/workspace/demo_ctas/files/personas/*`
ORDER BY id ASC;
